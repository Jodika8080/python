# %%
#convert celsius to farenheit
c=float(input("enter the temperature in celsius:")) 
f=(c*9/5)+32
print("the corresponding farenheit :",f)
# Out:
# enter the temperature in celsius: 120
# the corresponding farenheit : 248.0

# %%
#kilometer to miles
km=float(input("enter the distance in kilometers:"))
m=km*0.62137
print("the corresponding miles :",f"{m:.2f}")
# Out:
# enter the distance in kilometers: 2
# the corresponding miles : 1.24
