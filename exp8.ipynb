# %%
students = {}
for i in range(5):
    roll= int(input("enter roll numbr: "))
    name= input("enter student name:")
    students[roll]=name
    print("original dictionary:",students)
ascending=dict(sorted(students.items()))
print("ascending order:",ascending)
descending=dict(sorted(students.items(),reverse=True))
print("descending order:",descending)
# Out:
# enter roll numbr:  1
# enter student name: anu
# original dictionary: {1: 'anu'}
# enter roll numbr:  5
# enter student name: arun
# original dictionary: {1: 'anu', 5: 'arun'}
# enter roll numbr:  3
# enter student name: asha
# original dictionary: {1: 'anu', 5: 'arun', 3: 'asha'}
# enter roll numbr:  8
# enter student name: riya
# original dictionary: {1: 'anu', 5: 'arun', 3: 'asha', 8: 'riya'}
# enter roll numbr:  6
# enter student name: ajay
# original dictionary: {1: 'anu', 5: 'arun', 3: 'asha', 8: 'riya', 6: 'ajay'}
# ascending order: {1: 'anu', 3: 'asha', 5: 'arun', 6: 'ajay', 8: 'riya'}
# descending order: {8: 'riya', 6: 'ajay', 5: 'arun', 3: 'asha', 1: 'anu'}

# %%
dic1={1:"anu",5:"arun",3:"asha",8:"riya",6:"ajay"}
dic2={7:"kiran",8:"miya"}
dic1.update(dic2)
print("merged dictionary:",dic1)
# Out:
# merged dictionary: {1: 'anu', 5: 'arun', 3: 'asha', 8: 'miya', 6: 'ajay', 7: 'kiran'}
