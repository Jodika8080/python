# %%
colors=input("enter colors separeted by comma:")
color_list =colors.split(",")
print("first color:",color_list[0])
print("last color:",color_list[-1])
# Out:
# enter colors separeted by comma: red,blue,black,yellow
# first color: red
# last color: yellow

# %%
filename=input("enter file name:")
extension=filename.split(".")[-1]
print("extension:",extension)
# Out:
# enter file name: jodika.txt
# extension: txt

# %%
numbers=input("enter number separated by comma : ")
num_list=[int(x) for x in numbers.split(",")]
print("list:",num_list)
print("sum:",sum(num_list))
# Out:
# enter number separated by comma :  10,20,30,40
# list: [10, 20, 30, 40]
# sum: 100
