# %%
#all colors from colorset 1 not contain in color2
color_set1={"red","blue","green","yellow"}
color_set2={"black","green","pink"}
result=color_set1-color_set2
print("colors in set 1 not in set 2:",result)
# Out:
# colors in set 1 not in set 2: {'blue', 'red', 'yellow'}

# %%
#all color from color set 1 and colo set 2
color_set1={"red","blue","green","yellow"}
color_set2={"black","green","pink"}
result=color_set1 | color_set2
print("all colors :",result)
# Out:
# all colors : {'black', 'pink', 'blue', 'red', 'green', 'yellow'}
